# %%
import numpy as np
x = np.random.randint(1,20,15)
x
# Out:
# array([ 6,  7,  6, 19, 14,  6,  9,  6,  3,  5, 13, 14,  9, 15,  9])

# %%
x=x.reshape(3,5)
x
# Out:
# array([[ 6,  7,  6, 19, 14],
#        [ 6,  9,  6,  3,  5],
#        [13, 14,  9, 15,  9]])

# %%
x.shape
# Out:
# (3, 5)

# %%
for i in range(0,len(x)):
    max_ele = max(x[i])
    for j in range(0,len(x[i])):
        if x[i][j] == max_ele:
            x[i][j] = 0
x
# Out:
# array([[ 6,  7,  6,  0, 14],
#        [ 6,  0,  6,  3,  5],
#        [13, 14,  9,  0,  9]])

# %%
import pandas as pd
df=pd.read_csv("./data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
mean_value=df['Calories'].mean()

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
df['Calories'].fillna(value=mean_value,inplace=True)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.Duration.describe()
# Out:
# count    169.000000
# mean      63.846154
# std       42.299949
# min       15.000000
# 25%       45.000000
# 50%       60.000000
# 75%       60.000000
# max      300.000000
# Name: Duration, dtype: float64

# %%
df.Pulse.describe()
# Out:
# count    169.000000
# mean     107.461538
# std       14.510259
# min       80.000000
# 25%      100.000000
# 50%      105.000000
# 75%      111.000000
# max      159.000000
# Name: Pulse, dtype: float64

# %%
df[(df['Calories']>500) & (df['Calories']<1000)]
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df[(df['Calories']>500 & (df['Pulse']<100))]
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df_modified=df.drop("Maxpulse",axis=1)
df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df=df.drop("Maxpulse",axis=1)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df["Calories"] = df["Calories"].astype(float).astype(int)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]

# %%
df.plot.scatter(x = 'Duration', y = 'Calories')
# plot.show()
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
prgmng_df=pd.DataFrame({"popularity":[22.2, 17.6, 8.8, 8, 7.7, 6.7]},index=['Java','Python','PHP','JavaScript', 'C#', 'C++'])
prgmng_df.explode('popularity')
prgmng_df
# Out:
#             popularity
# Java              22.2
# Python            17.6
# PHP                8.8
# JavaScript         8.0
# C#                 7.7
# C++                6.7

# %%
myexplode = [0.2, 0, 0, 0,0,0]
prgmng_df.plot.pie(y='popularity',autopct='%1.1f%%',explode=myexplode,figsize=[10,10],startangle=140)
# Out:
# <AxesSubplot:ylabel='popularity'>
